# %% [markdown]
# 1. Setup and Libraries

# %%
import pandas as pd          
import numpy as np           
import matplotlib.pyplot as plt  
import seaborn as sns        
import pm4py
import sys
print(sys.executable)
# Out:
# /Users/simonimmler/PycharmProjects/Praktikum/bpic_project/.venv/bin/python3
