# %% [markdown]
# 1. Setup and Libraries

# %%
import pandas as pd          
import numpy as np           
import matplotlib.pyplot as plt  
import seaborn as sns        
import pm4py

# %% [markdown]
# 2. Read out the xes file

# %%
from pm4py.objects.log.importer.xes import importer as xes_importer
LOG_PATH = '/Users/simonimmler/PycharmProjects/Praktikum/data/BPI Challenge 2017.xes'  # Pfad anpassen
log = xes_importer.apply(LOG_PATH)
# Out:
# parsing log, completed traces ::   0%|          | 0/31509 [00:00<?, ?it/s]

# %% [markdown]
# # 3.1. Basic Analysis

# %%
df = pm4py.convert_to_dataframe(log)
pd.set_option('display.max_rows', 200)       # Anzahl Zeilen
pd.set_option('display.max_columns', None)   # alle Spalten
pd.set_option('display.width', 0)            # volle Breite
pd.set_option('display.max_colwidth', None)  # kein Spalten-Cut

df.head(100)
# Out:
#          Action org:resource              concept:name  EventOrigin  \
# 0       Created       User_1      A_Create Application  Application
# 1   statechange       User_1               A_Submitted  Application
# 2       Created       User_1            W_Handle leads     Workflow
# 3       Deleted       User_1            W_Handle leads     Workflow
# 4       Created       User_1    W_Complete application     Workflow
# 5   statechange       User_1                 A_Concept  Application
# 6      Obtained      User_17    W_Complete application     Workflow
# 7      Released      User_17    W_Complete application     Workflow
# 8   statechange      User_52                A_Accepted  Application
# 9       Created      User_52            O_Create Offer        Offer
# 10  statechange      User_52                 O_Created        Offer
# 11  statechange      User_52  O_Sent (mail and online)        Offer
# 12      Deleted      User_52    W_Complete application     Workflow
# 13      Created      User_52       W_Call after offers     Workflow
# 14     Obtained      User_52       W_Call after offers     Workflow
# 15  statechange      User_52                A_Complete  Application
# 16     Released      User_52       W_Call after offers     Workflow
# 17     Obtained      User_11       W_Call after offers     Workflow
# 18     Released      User_11       W_Call after offers     Workflow
# 19      Deleted     User_117       W_Call after offers     Workflow
# 20      Created     User_117    W_Validate application     Workflow
# 21     Obtained     User_117    W_Validate application     Workflow
# 22  statechange     User_117              A_Validating  Application
# 23  statechange     User_117                O_Returned        Offer
# 24     Released     User_117    W_Validate application     Workflow
# 25      Deleted     User_115    W_Validate application     Workflow
# 26      Created     User_115   W_Call incomplete files     Workflow
# 27     Obtained     User_115   W_Call incomplete files     Workflow
# 28  statechange     User_115              A_Incomplete  Application
# 29     Released     User_115   W_Call incomplete files     Workflow
# 30     Obtained       User_2   W_Call incomplete files     Workflow
# 31     Released       User_2   W_Call incomplete files     Workflow
# 32      Deleted     User_117   W_Call incomplete files     Workflow
# 33      Created     User_117    W_Validate application     Workflow
# 34     Obtained     User_117    W_Validate application     Workflow
# 35  statechange     User_117              A_Validating  Application
# 36     Released     User_117    W_Validate application     Workflow
# 37  statechange     User_115                O_Accepted        Offer
# 38  statechange     User_115                 A_Pending  Application
# 39      Deleted     User_115    W_Validate application     Workflow
# 40      Created       User_1      A_Create Application  Application
# 41  statechange       User_1               A_Submitted  Application
# 42      Created       User_1            W_Handle leads     Workflow
# 43      Deleted       User_1            W_Handle leads     Workflow
# 44      Created       User_1    W_Complete application     Workflow
# 45  statechange       User_1                 A_Concept  Application
# 46     Obtained      User_17    W_Complete application     Workflow
# 47     Released      User_17    W_Complete application     Workflow
# 48     Obtained      User_38    W_Complete application     Workflow
# 49  statechange      User_38                A_Accepted  Application
# 50      Created      User_38            O_Create Offer        Offer
# 51  statechange      User_38                 O_Created        Offer
# 52  statechange      User_38  O_Sent (mail and online)        Offer
# 53      Deleted      User_38    W_Complete application     Workflow
# 54      Created      User_38       W_Call after offers     Workflow
# 55     Obtained      User_38       W_Call after offers     Workflow
# 56  statechange      User_38                A_Complete  Application
# 57     Released      User_38       W_Call after offers     Workflow
# 58     Obtained      User_11       W_Call after offers     Workflow
# 59     Released      User_11       W_Call after offers     Workflow
# 60      Deleted     User_119       W_Call after offers     Workflow
# 61      Created     User_119    W_Validate application     Workflow
# 62     Obtained     User_119    W_Validate application     Workflow
# 63  statechange     User_119              A_Validating  Application
# 64     Released     User_119    W_Validate application     Workflow
# 65     Obtained      User_30    W_Validate application     Workflow
# 66     Released      User_30    W_Validate application     Workflow
# 67     Obtained      User_68    W_Validate application     Workflow
# 68  statechange      User_68                  A_Denied  Application
# 69  statechange      User_68                 O_Refused        Offer
# 70      Deleted      User_68    W_Validate application     Workflow
# 71      Created       User_1      A_Create Application  Application
# 72  statechange       User_1               A_Submitted  Application
# 73      Created       User_1            W_Handle leads     Workflow
# 74      Deleted       User_1            W_Handle leads     Workflow
# 75      Created       User_1    W_Complete application     Workflow
# 76  statechange       User_1                 A_Concept  Application
# 77     Obtained      User_19    W_Complete application     Workflow
# 78  statechange      User_19                A_Accepted  Application
# 79      Created      User_19            O_Create Offer        Offer
# 80  statechange      User_19                 O_Created        Offer
# 81  statechange      User_19  O_Sent (mail and online)        Offer
# 82      Deleted      User_19    W_Complete application     Workflow
# 83      Created      User_19       W_Call after offers     Workflow
# 84     Obtained      User_19       W_Call after offers     Workflow
# 85  statechange      User_19                A_Complete  Application
# 86     Released      User_19       W_Call after offers     Workflow
# 87      Created      User_19            O_Create Offer        Offer
# 88  statechange      User_19                 O_Created        Offer
# 89  statechange      User_19               O_Cancelled        Offer
# 90  statechange      User_19  O_Sent (mail and online)        Offer
# 91     Obtained      User_11       W_Call after offers     Workflow
# 92     Released      User_11       W_Call after offers     Workflow
# 93      Deleted     User_116       W_Call after offers     Workflow
# 94      Created     User_116    W_Validate application     Workflow
# 95     Obtained     User_116    W_Validate application     Workflow
# 96  statechange     User_116              A_Validating  Application
# 97  statechange     User_116                O_Returned        Offer
# 98     Released     User_116    W_Validate application     Workflow
# 99      Deleted     User_101    W_Validate application     Workflow
#
#                    EventID lifecycle:transition  \
# 0    Application_652823628             complete
# 1     ApplState_1582051990             complete
# 2      Workitem_1298499574             schedule
# 3      Workitem_1673366067             withdraw
# 4      Workitem_1493664571             schedule
# 5      ApplState_642383566             complete
# 6      Workitem_1875340971                start
# 7      Workitem_1452291795              suspend
# 8       ApplState_99568828             complete
# 9          Offer_148581083             complete
# 10   OfferState_1514834199             complete
# 11   OfferState_2051164740             complete
# 12     Workitem_1007505836            ate_abort
# 13     Workitem_1087320491             schedule
# 14      Workitem_719909876                start
# 15     ApplState_946455804             complete
# 16     Workitem_1447720177              suspend
# 17     Workitem_1260329040               resume
# 18     Workitem_1152103512              suspend
# 19      Workitem_524990185            ate_abort
# 20      Workitem_781654767             schedule
# 21     Workitem_1641716416                start
# 22     ApplState_752879093             complete
# 23   OfferState_1310330551             complete
# 24      Workitem_823786158              suspend
# 25      Workitem_392297123            ate_abort
# 26      Workitem_835564623             schedule
# 27     Workitem_2031858979                start
# 28     ApplState_390139749             complete
# 29     Workitem_1628953525              suspend
# 30      Workitem_943086771               resume
# 31       Workitem_50564835              suspend
# 32     Workitem_1225999065            ate_abort
# 33      Workitem_801031108             schedule
# 34     Workitem_2071763612                start
# 35    ApplState_1264188685             complete
# 36      Workitem_646578909              suspend
# 37   OfferState_1093322349             complete
# 38    ApplState_1179730815             complete
# 39     Workitem_2067229931            ate_abort
# 40  Application_1691306052             complete
# 41     ApplState_284636842             complete
# 42      Workitem_831373279             schedule
# 43     Workitem_1299098074             withdraw
# 44     Workitem_1703931302             schedule
# 45     ApplState_421204851             complete
# 46     Workitem_1746553641                start
# 47     Workitem_1713535355              suspend
# 48     Workitem_1495694398               resume
# 49     ApplState_525970231             complete
# 50        Offer_1669071500             complete
# 51    OfferState_680973097             complete
# 52    OfferState_618588716             complete
# 53       Workitem_28216352             complete
# 54       Workitem_81733400             schedule
# 55      Workitem_107760987                start
# 56     ApplState_173433077             complete
# 57      Workitem_635624695              suspend
# 58     Workitem_1059415130               resume
# 59       Workitem_47243651              suspend
# 60     Workitem_1908827665            ate_abort
# 61      Workitem_960318560             schedule
# 62      Workitem_736976847                start
# 63    ApplState_2031628358             complete
# 64      Workitem_338353106              suspend
# 65     Workitem_1522720538               resume
# 66      Workitem_313764426              suspend
# 67     Workitem_1377364007               resume
# 68    ApplState_1181660825             complete
# 69   OfferState_1494429296             complete
# 70       Workitem_72878931             complete
# 71   Application_428409768             complete
# 72     ApplState_105207793             complete
# 73     Workitem_1185806608             schedule
# 74      Workitem_835967796             withdraw
# 75      Workitem_755889823             schedule
# 76    ApplState_1727723699             complete
# 77       Workitem_62767814                start
# 78     ApplState_504362841             complete
# 79        Offer_1209840642             complete
# 80    OfferState_942949889             complete
# 81    OfferState_253970058             complete
# 82     Workitem_2003414398             complete
# 83     Workitem_1530416988             schedule
# 84     Workitem_1340137029                start
# 85     ApplState_864110001             complete
# 86     Workitem_1717804686              suspend
# 87         Offer_997411923             complete
# 88   OfferState_1967587147             complete
# 89   OfferState_1893960455             complete
# 90    OfferState_600565321             complete
# 91     Workitem_1081743155               resume
# 92     Workitem_1371373781              suspend
# 93     Workitem_1500398862            ate_abort
# 94      Workitem_426017595             schedule
# 95     Workitem_1121078170                start
# 96     ApplState_145257449             complete
# 97    OfferState_836197344             complete
# 98     Workitem_1394551701              suspend
# 99     Workitem_2084533572            ate_abort
#
#                      time:timestamp           case:LoanGoal  \
# 0  2016-01-01 09:51:15.304000+00:00  Existing loan takeover
# 1  2016-01-01 09:51:15.352000+00:00  Existing loan takeover
# 2  2016-01-01 09:51:15.774000+00:00  Existing loan takeover
# 3  2016-01-01 09:52:36.392000+00:00  Existing loan takeover
# 4  2016-01-01 09:52:36.403000+00:00  Existing loan takeover
# 5  2016-01-01 09:52:36.413000+00:00  Existing loan takeover
# 6  2016-01-02 10:45:22.429000+00:00  Existing loan takeover
# 15           New credit   Application_652823628               20000.0
# 16           New credit   Application_652823628               20000.0
# 17           New credit   Application_652823628               20000.0
# 18           New credit   Application_652823628               20000.0
# 19           New credit   Application_652823628               20000.0
# 20           New credit   Application_652823628               20000.0
# 21           New credit   Application_652823628               20000.0
# 22           New credit   Application_652823628               20000.0
# 23           New credit   Application_652823628               20000.0
# 24           New credit   Application_652823628               20000.0
# 25           New credit   Application_652823628               20000.0
# 26           New credit   Application_652823628               20000.0
# 27           New credit   Application_652823628               20000.0
# 28           New credit   Application_652823628               20000.0
# 29           New credit   Application_652823628               20000.0
# 30           New credit   Application_652823628               20000.0
# 31           New credit   Application_652823628               20000.0
# 32           New credit   Application_652823628               20000.0
# 33           New credit   Application_652823628               20000.0
# 34           New credit   Application_652823628               20000.0
# 35           New credit   Application_652823628               20000.0
# 36           New credit   Application_652823628               20000.0
# 37           New credit   Application_652823628               20000.0
# 38           New credit   Application_652823628               20000.0
# 39           New credit   Application_652823628               20000.0
# 40           New credit  Application_1691306052               10000.0
# 41           New credit  Application_1691306052               10000.0
# 42           New credit  Application_1691306052               10000.0
# 43           New credit  Application_1691306052               10000.0
# 44           New credit  Application_1691306052               10000.0
# 45           New credit  Application_1691306052               10000.0
# 46           New credit  Application_1691306052               10000.0
# 47           New credit  Application_1691306052               10000.0
# 48           New credit  Application_1691306052               10000.0
# 49           New credit  Application_1691306052               10000.0
# 50           New credit  Application_1691306052               10000.0
# 51           New credit  Application_1691306052               10000.0
# 52           New credit  Application_1691306052               10000.0
# 53           New credit  Application_1691306052               10000.0
# 54           New credit  Application_1691306052               10000.0
# 55           New credit  Application_1691306052               10000.0
# 56           New credit  Application_1691306052               10000.0
# 57           New credit  Application_1691306052               10000.0
# 58           New credit  Application_1691306052               10000.0
# 59           New credit  Application_1691306052               10000.0
# 60           New credit  Application_1691306052               10000.0
# 61           New credit  Application_1691306052               10000.0
# 62           New credit  Application_1691306052               10000.0
# 63           New credit  Application_1691306052               10000.0
# 64           New credit  Application_1691306052               10000.0
# 65           New credit  Application_1691306052               10000.0
# 66           New credit  Application_1691306052               10000.0
# 67           New credit  Application_1691306052               10000.0
# 68           New credit  Application_1691306052               10000.0
# 69           New credit  Application_1691306052               10000.0
# 70           New credit  Application_1691306052               10000.0
# 71           New credit   Application_428409768               15000.0
# 72           New credit   Application_428409768               15000.0
# 73           New credit   Application_428409768               15000.0
# 74           New credit   Application_428409768               15000.0
# 75           New credit   Application_428409768               15000.0
# 76           New credit   Application_428409768               15000.0
# 77           New credit   Application_428409768               15000.0
# 78           New credit   Application_428409768               15000.0
# 79           New credit   Application_428409768               15000.0
# 80           New credit   Application_428409768               15000.0
# 81           New credit   Application_428409768               15000.0
# 82           New credit   Application_428409768               15000.0
# 83           New credit   Application_428409768               15000.0
# 84           New credit   Application_428409768               15000.0
# 85           New credit   Application_428409768               15000.0
# 86           New credit   Application_428409768               15000.0
# 87           New credit   Application_428409768               15000.0
# 88           New credit   Application_428409768               15000.0
# 89           New credit   Application_428409768               15000.0
# 90           New credit   Application_428409768               15000.0
# 91           New credit   Application_428409768               15000.0
# 92           New credit   Application_428409768               15000.0
# 93           New credit   Application_428409768               15000.0
# 94           New credit   Application_428409768               15000.0
# 95           New credit   Application_428409768               15000.0
# 96           New credit   Application_428409768               15000.0
# 97           New credit   Application_428409768               15000.0
# 98           New credit   Application_428409768               15000.0
# 99           New credit   Application_428409768               15000.0
#
#     FirstWithdrawalAmount  NumberOfTerms Accepted  MonthlyCost Selected  \
# 0
# 59                    NaN            NaN      NaN          NaN      NaN
# 60                    NaN            NaN      NaN          NaN      NaN
# 61                    NaN            NaN      NaN          NaN      NaN
# 62                    NaN            NaN      NaN          NaN      NaN
# 63                    NaN            NaN      NaN          NaN      NaN
# 64                    NaN            NaN      NaN          NaN      NaN
# 65                    NaN            NaN      NaN          NaN      NaN
# 66                    NaN            NaN      NaN          NaN      NaN
# 67                    NaN            NaN      NaN          NaN      NaN
# 68                    NaN            NaN      NaN          NaN      NaN
# 69                    NaN            NaN      NaN          NaN      NaN
# 70                    NaN            NaN      NaN          NaN      NaN
# 71                    NaN            NaN      NaN          NaN      NaN
# 72                    NaN            NaN      NaN          NaN      NaN
# 73                    NaN            NaN      NaN          NaN      NaN
# 74                    NaN            NaN      NaN          NaN      NaN
# 75                    NaN            NaN      NaN          NaN      NaN
# 76                    NaN            NaN      NaN          NaN      NaN
# 77                    NaN            NaN      NaN          NaN      NaN
# 78                    NaN            NaN      NaN          NaN      NaN
# 79                15000.0          120.0     True       158.98    False
# 80                    NaN            NaN      NaN          NaN      NaN
# 81                    NaN            NaN      NaN          NaN      NaN
# 82                    NaN            NaN      NaN          NaN      NaN
# 83                    NaN            NaN      NaN          NaN      NaN
# 84                    NaN            NaN      NaN          NaN      NaN
# 85                    NaN            NaN      NaN          NaN      NaN
# 86                    NaN            NaN      NaN          NaN      NaN
# 87                15000.0          120.0     True       158.98     True
# 88                    NaN            NaN      NaN          NaN      NaN
# 89                    NaN            NaN      NaN          NaN      NaN
# 90                    NaN            NaN      NaN          NaN      NaN
# 91                    NaN            NaN      NaN          NaN      NaN
# 92                    NaN            NaN      NaN          NaN      NaN
# 93                    NaN            NaN      NaN          NaN      NaN
# 94                    NaN            NaN      NaN          NaN      NaN
# 95                    NaN            NaN      NaN          NaN      NaN
# 96                    NaN            NaN      NaN          NaN      NaN
# 97                    NaN            NaN      NaN          NaN      NaN
# 98                    NaN            NaN      NaN          NaN      NaN
# 99                    NaN            NaN      NaN          NaN      NaN
#
#     CreditScore  OfferedAmount           OfferID
# 0           NaN            NaN               NaN
# 1           NaN            NaN               NaN
# 2           NaN            NaN               NaN
# 3           NaN            NaN               NaN
# 4           NaN            NaN               NaN
# 5           NaN            NaN               NaN
# 6           NaN            NaN               NaN
# 7           NaN            NaN               NaN
# 8           NaN            NaN               NaN
# 9         979.0        20000.0               NaN
# 10          NaN            NaN   Offer_148581083
# 11          NaN            NaN   Offer_148581083
# 12          NaN            NaN               NaN
# 13          NaN            NaN               NaN
# 14          NaN            NaN               NaN
# 15          NaN            NaN               NaN
# 16          NaN            NaN               NaN
# 17          NaN            NaN               NaN
# 18          NaN            NaN               NaN
# 19          NaN            NaN               NaN
# 20          NaN            NaN               NaN
# 21          NaN            NaN               NaN
# 22          NaN            NaN               NaN
# 23          NaN            NaN   Offer_148581083
# 24          NaN            NaN               NaN
# 25          NaN            NaN               NaN
# 26          NaN            NaN               NaN
# 27          NaN            NaN               NaN
# 28          NaN            NaN               NaN
# 29          NaN            NaN               NaN
# 30          NaN            NaN               NaN
# 31          NaN            NaN               NaN
# 32          NaN            NaN               NaN
# 33          NaN            NaN               NaN
# 34          NaN            NaN               NaN
# 35          NaN            NaN               NaN
# 36          NaN            NaN               NaN
# 37          NaN            NaN   Offer_148581083
# 38          NaN            NaN               NaN
# 39          NaN            NaN               NaN
# 40          NaN            NaN               NaN
# 41          NaN            NaN               NaN
# 42          NaN            NaN               NaN
# 43          NaN            NaN               NaN
# 44          NaN            NaN               NaN
# 45          NaN            NaN               NaN
# 46          NaN            NaN               NaN
# 47          NaN            NaN               NaN
# 48          NaN            NaN               NaN
# 49          NaN            NaN               NaN
# 50          0.0         6000.0               NaN
# 51          NaN            NaN  Offer_1669071500
# 52          NaN            NaN  Offer_1669071500
# 53          NaN            NaN               NaN
# 54          NaN            NaN               NaN
# 55          NaN            NaN               NaN
# 56          NaN            NaN               NaN
# 57          NaN            NaN               NaN
# 58          NaN            NaN               NaN
# 59          NaN            NaN               NaN
# 60          NaN            NaN               NaN
# 61          NaN            NaN               NaN
# 62          NaN            NaN               NaN
# 63          NaN            NaN               NaN
# 64          NaN            NaN               NaN
# 65          NaN            NaN               NaN
# 66          NaN            NaN               NaN
# 67          NaN            NaN               NaN
# 68          NaN            NaN               NaN
# 69          NaN            NaN  Offer_1669071500
# 70          NaN            NaN               NaN
# 71          NaN            NaN               NaN
# 72          NaN            NaN               NaN
# 73          NaN            NaN               NaN
# 74          NaN            NaN               NaN
# 75          NaN            NaN               NaN
# 76          NaN            NaN               NaN
# 77          NaN            NaN               NaN
# 78          NaN            NaN               NaN
# 79          0.0        15000.0               NaN
# 80          NaN            NaN  Offer_1209840642
# 81          NaN            NaN  Offer_1209840642
# 82          NaN            NaN               NaN
# 83          NaN            NaN               NaN
# 84          NaN            NaN               NaN
# 85          NaN            NaN               NaN
# 86          NaN            NaN               NaN
# 87       1059.0        15000.0               NaN
# 88          NaN            NaN   Offer_997411923
# 89          NaN            NaN  Offer_1209840642
# 90          NaN            NaN   Offer_997411923
# 91          NaN            NaN               NaN
# 92          NaN            NaN               NaN
# 93          NaN            NaN               NaN
# 94          NaN            NaN               NaN
# 95          NaN            NaN               NaN
# 96          NaN            NaN               NaN
# 97          NaN            NaN   Offer_997411923
# 98          NaN            NaN               NaN
# 99          NaN            NaN               NaN

# %% [markdown]
# a) Count Cases

# %%
num_cases = len(log)
print(f"Cases: {num_cases}")
# print(log.count(0))
# Out:
# Cases: 31509

# %% [markdown]
# b) Count Events (after Filtering in 3.3_Process_Model_Creation_and_Validation)

# %%
num_events = sum(len(trace) for trace in log)
print(f"Events: {num_events}")
# Out:
# Events: 1202267

# %% [markdown]
# c) different Variants (after Filtering in 3.3_Process_Model_Creation_and_Validation)

# %%
variants = pm4py.get_variants(log)
num_variants = len(variants)
print(f"Variants: {num_variants}")
# Out:
# Variants: 15930

# %% [markdown]
# d) Mean case length and standard deviation of case length

# %%
case_lengths = [len(trace) for trace in log]
print(f"Mean case length: {np.mean(case_lengths):.2f}")
print(f"Standard devation of case length: {np.std(case_lengths):.2f}")
# Out:
# Mean case length: 38.16
# Standard devation of case length: 16.72

# %% [markdown]
# e) Mean case duration and standard deviation of case duration

# %%
case_durations = pm4py.get_all_case_durations(log)  # in seconds

mean_sec = np.mean(case_durations)
std_sec  = np.std(case_durations)

def format_dms(seconds):
    days = int(seconds // 86400)
    rest = seconds % 86400
    minutes = int(rest // 60)
    secs = int(rest % 60)
    return f"{days} days, {minutes} minutes, {secs} seconds"

print("Mean case duration:", format_dms(mean_sec))
print("Standard deviation of case duration:", format_dms(std_sec))
# Out:
# Mean case duration: 21 days, 1295 minutes, 25 seconds
# Standard deviation of case duration: 13 days, 243 minutes, 23 seconds

# %% [markdown]
# f) event labels and case labels

# %%
event_attrs = pm4py.get_event_attributes(log)
cleaned_ev_attr = sorted([a for a in event_attrs if "case:" not in a])
print("Event attributes:", cleaned_ev_attr)
print("Number of event labels:", len(cleaned_ev_attr))

case_attrs = pm4py.get_trace_attributes(log)
print("Case attributes:", case_attrs)
print("Number of case labels:", len(case_attrs))
# Out:
# Event attributes: ['Accepted', 'Action', 'CreditScore', 'EventID', 'EventOrigin', 'FirstWithdrawalAmount', 'MonthlyCost', 'NumberOfTerms', 'OfferID', 'OfferedAmount', 'Selected', 'concept:name', 'org:resource', 'time:timestamp']
# Number of event labels: 14
# Case attributes: ['ApplicationType', 'RequestedAmount', 'LoanGoal']
# Number of case labels: 3

# %% [markdown]
# g) Number of categorical event attributes (incl ids)

# %%
categorical_event_attrs = []
for col in cleaned_ev_attr:
    if df[col].dtype == "object":  
        categorical_event_attrs.append(col)

print("Categorical event attributes:", categorical_event_attrs)
print("Number of categorical event attributes:", len(categorical_event_attrs))
# Out:
# Categorical event attributes: ['Accepted', 'Action', 'EventID', 'EventOrigin', 'OfferID', 'Selected', 'concept:name', 'org:resource']
# Number of categorical event attributes: 8

# %% [markdown]
# h) (optional) Events per Day

# %%
df = pm4py.convert_to_dataframe(log)
df["date"] = pd.to_datetime(df["time:timestamp"]).dt.date
events_per_day = df.groupby("date").size().mean()

print(f"Average number of events per day: {events_per_day:.2f}")
# Out:
# Average number of events per day: 3020.77

# %%
#print("Unique dates", df["date"].nunique())
#print(df["date"].min(), "bis", df["date"].max())
#print(df["date"].value_counts().sort_index().head(100))

# %% [markdown]
# i) (optional) most frequent activities

# %%
top_n = df["concept:name"].value_counts()
print(top_n.head(15))
# Out:
# concept:name
# W_Validate application      209496
# W_Call after offers         191092
# W_Call incomplete files     168529
# W_Complete application      148900
# W_Handle leads               47264
# O_Create Offer               42995
# O_Created                    42995
# O_Sent (mail and online)     39707
# A_Validating                 38816
# A_Create Application         31509
# A_Concept                    31509
# A_Accepted                   31509
# A_Complete                   31362
# O_Returned                   23305
# A_Incomplete                 23055
# Name: count, dtype: int64

# %% [markdown]
# j) (optional) shortest and longest durations of the cases

# %%
df1 = df.copy()
df1 = df1.dropna(subset=["time:timestamp", "case:concept:name"])
df1["ts"] = pd.to_datetime(df1["time:timestamp"], utc=True, errors="coerce")
df1 = df1.dropna(subset=["ts"])

span = df1.groupby("case:concept:name")["ts"].agg(first_ts="min", last_ts="max")
span["duration_days"] = (span["last_ts"] - span["first_ts"]).dt.total_seconds() / 86400

min_d = span["duration_days"].min()
max_d = span["duration_days"].max()
print(f"shortest duration: {min_d*24*60:.4f} min | longest duration: {max_d:.2f} days")
# Out:
# shortest duration: 3.3510 min | longest duration: 286.07 days
